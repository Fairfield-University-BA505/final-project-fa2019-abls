# %%
# Import pandas
import pandas as pd
# Import matplotlib to plot data
import matplotlib.pylab as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
# Import data set
wine_data_program = pd.read_csv('wine_data.csv')
# Visualize data set
wine_data_program.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
# Remove the region columns from the dataset because more than 50% of the values are missing 
wine_data_program.drop(['Unnamed: 0', 'region_2'], inplace=True, axis=1)
# Visualize the dataset to ensure column was dropped
wine_data_program
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                     NaN      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                     NaN      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1         taster_name  \
# 0       Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1                   Douro                  NaN          Roger Voss
# 2                  Oregon    Willamette Valley        Paul Gregutt
# 3                Michigan  Lake Michigan Shore  Alexander Peartree
# 4                  Oregon    Willamette Valley        Paul Gregutt
# ...                   ...                  ...                 ...
# 129966              Mosel                  NaN  Anna Lee C. Iijima
# 129967             Oregon               Oregon        Paul Gregutt
# 129968             Alsace               Alsace          Roger Voss
# 129969             Alsace               Alsace          Roger Voss
# 129970             Alsace               Alsace          Roger Voss
#
#        taster_twitter_handle  \
# 0               @kerinokeefe
# 1                 @vossroger
# 2                @paulgwine
# 3                        NaN
# 4                @paulgwine
# ...                      ...
# 129966                   NaN
# 129967           @paulgwine
# 129968            @vossroger
# 129969            @vossroger
# 129970            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [129971 rows x 12 columns]

# %%
# Replace missing values with the average for the column because they are continuous values
wine_data_program['price'] = wine_data_program['price'].fillna(wine_data_program['price'].mean())
# Check to see if all values are filled
wine_data_program.isnull().mean()*100
# Out:
# country                   0.048472
# description               0.000000
# designation              28.825661
# points                    0.000000
# price                     0.000000
# province                  0.048472
# region_1                 16.347493
# taster_name              20.192197
# taster_twitter_handle    24.015357
# title                     0.000000
# variety                   0.000769
# winery                    0.000000
# dtype: float64

# %%
# Add column to wine_data set to analyze data by points per dollar
wine_data_program['Value']=wine_data_program['points']/wine_data_program['price']
wine_data_program.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points      price           province  \
# 0                        Vulkà Bianco      87  35.363389  Sicily & Sardinia
# 1                            Avidagos      87  15.000000              Douro
# 2                                 NaN      87  14.000000             Oregon
# 3                Reserve Late Harvest      87  13.000000           Michigan
# 4  Vintner's Reserve Wild Child Block      87  65.000000             Oregon
#
#               region_1         taster_name taster_twitter_handle  \
# 0                 Etna       Kerin O’Keefe          @kerinokeefe
# 1                  NaN          Roger Voss            @vossroger
# 2    Willamette Valley        Paul Gregutt           @paulgwine
# 3  Lake Michigan Shore  Alexander Peartree                   NaN
# 4    Willamette Valley        Paul Gregutt           @paulgwine
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery     Value
# 0              Nicosia  2.460171
# 1  Quinta dos Avidagos  5.800000
# 2            Rainstorm  6.214286
# 3           St. Julian  6.692308
# 4         Sweet Cheeks  1.338462

# %%
def wine_recommend():
    try:
        print("Please enter your desired wine country: ")
        country_input = input()
        print("Please enter your desired wine variety: ")
        variety_input = input()
        print('Please enter your desired price: ')
        price_input= float(input())
        print('Please enter your desired points: ')
        points_input = int(input())
        rec_df = wine_data_program[(wine_data_program.country==country_input) & (wine_data_program.variety==variety_input) & (wine_data_program.price <= price_input) & (wine_data_program.points >= points_input)].sort_values('points', ascending = 0)
        return(rec_df.head(10))
   
    except:
        print('Input Error, please enter a valid input')

# %%
wine_recommend()
# Out:
# Please enter your desired wine country:
#  US
# Please enter your desired wine variety:
#  White Blend
# Please enter your desired price:
#  50
# Please enter your desired points:
#  80
#        country                                        description  \
# 78296       US  This marks another stunning vintage for this b...
# 45814       US  Among McCrea's Rhône-inspired white wines, thi...
# 51890       US  This blend of Roussanne, Chardonnay and Viogni...
# 67639       US  Based on a blend from the era of Charlemagne, ...
# 59401       US  An old-vine field blend of Gewürztraminer, Tro...
# 25401       US  Light and floral, this subtle dessert wine is ...
# 1448        US  2014 proves another banner year for this delig...
# 104462      US  This is an unusual blend of 55% Sauvignon Blan...
# 43903       US  This blend of 35% Chardonnay, 35% Pinot Blanc ...
# 123783      US  A stunning field blend of Gewürztraminer, Trou...
#
#                            designation  points  price    province  \
# 78296                   The Derivative      95   28.0  California
# 45814   Boushey Vineyard Sirocco Blanc      95   25.0  Washington
# 51890         Incandescent Proprietary      94   50.0  California
# 67639                        Hildegard      94   35.0  California
# 59401                  Compagni Portis      94   30.0  California
# 25401                          Eisrébe      94   50.0  California
# 1448                    The Derivative      94   28.0  California
# 104462                        Blend 23      93   39.0  California
# 43903                            Fonte      93   36.0  California
# 123783                 Compagni Portis      93   34.0  California
#
#                     region_1     taster_name taster_twitter_handle  \
# 78296          Sonoma County  Virginie Boone               @vboone
# 45814          Yakima Valley    Paul Gregutt           @paulgwine
# 51890   Santa Barbara County             NaN                   NaN
# 67639     Santa Maria Valley   Matt Kettmann         @mattkettmann
# 59401          Sonoma Valley  Virginie Boone               @vboone
# 25401            Napa Valley  Virginie Boone               @vboone
# 1448           Sonoma County  Virginie Boone               @vboone
# 104462           Napa Valley  Virginie Boone               @vboone
# 43903        Sta. Rita Hills   Matt Kettmann         @mattkettmann
# 123783         Sonoma Valley  Virginie Boone               @vboone
#
#                                                     title      variety  \
# 78296   Carlisle 2013 The Derivative White (Sonoma Cou...  White Blend
# 45814   McCrea 2008 Boushey Vineyard Sirocco Blanc Whi...  White Blend
# 51890   Sanguis 2011 Incandescent Proprietary White (S...  White Blend
# 67639   Au Bon Climat 2014 Hildegard White (Santa Mari...  White Blend
# 59401   Carlisle 2015 Compagni Portis White (Sonoma Va...  White Blend
# 25401      Joseph Phelps 2013 Eisrébe White (Napa Valley)  White Blend
# 1448    Carlisle 2014 The Derivative White (Sonoma Cou...  White Blend
# 104462        B Cellars 2013 Blend 23 White (Napa Valley)  White Blend
# 43903           Barden 2015 Fonte White (Sta. Rita Hills)  White Blend
# 123783  Carlisle 2013 Compagni Portis White (Sonoma Va...  White Blend
#
#                winery     Value
# 78296        Carlisle  3.392857
# 45814          McCrea  3.800000
# 51890         Sanguis  1.880000
# 67639   Au Bon Climat  2.685714
# 59401        Carlisle  3.133333
# 25401   Joseph Phelps  1.880000
# 1448         Carlisle  3.357143
# 104462      B Cellars  2.384615
# 43903          Barden  2.583333
# 123783       Carlisle  2.735294
