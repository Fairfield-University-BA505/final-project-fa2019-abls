# %%
# Import pandas
import pandas as pd
# Import matplotlib to plot data
import matplotlib.pylab as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
# Import data set
wine_data = pd.read_csv('wine_data.csv')
# Visualize data set
wine_data
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
#We determined the most popular variety of wines, this is so we can give reccomendations based on wines that people will be interested in drinking

grouped_wine= wine_data.groupby(['variety']).count()

grouped_wine['title'].sort_values(ascending=False).head(10)
# Out:
# variety
# Pinot Noir                  13272
# Chardonnay                  11753
# Cabernet Sauvignon           9472
# Red Blend                    8946
# Bordeaux-style Red Blend     6915
# Riesling                     5189
# Sauvignon Blanc              4967
# Syrah                        4142
# Rosé                         3564
# Merlot                       3102
# Name: title, dtype: int64

# %%
#We found popular wineries so people can look out for these when they are shopping for wine
grouped_winery=wine_data.groupby(['winery']).count()
grouped_winery['title'].sort_values(ascending=False).head(10)
# Out:
# winery
# Wines & Winemakers       222
# Testarossa               218
# DFJ Vinhos               215
# Williams Selyem          211
# Louis Latour             199
# Georges Duboeuf          196
# Chateau Ste. Michelle    194
# Concha y Toro            164
# Columbia Crest           159
# Kendall-Jackson          130
# Name: title, dtype: int64

# %% [markdown]
# | Feature Name | Definition | Key |
# | ------------ | ---------- | --- |
# | Country | Country where wine is produced | ... |
# | Description| Sommelier's description of the wine | ... |
# | Designation | Vineyard within the winery where the grapes that made the wine are from | ... |
# | Points | Points wine enthusiasts rated the wine | 80 - 100 |
# | Price | Selling price per bottle | `$`4 - `$`3,300 |
# | Province| Province or state the wine is produced in | ... |
# | Region_1| The wine growing area in a province or state  | ... |
# | Region_2 | The more specific region | ... |
# | Taster_name| The wine enthusiasts name | ... |
# | Taster_twitter_handle | The twitter account associated with the taster | ... |
# | Title | Title of the wine review | ... |
# | Variety | The type of grapes used to make the wine | ... |
# | Winery | The winery that produced the wine | ... |

# %%
# Visualize the data
wine_data.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
# Analyze first few entries to ensure data is loaded properly
wine_data.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
# Check to see how many data is missing from our data set
wine_data.isna().any()
# Out:
# Unnamed: 0               False
# country                   True
# description              False
# designation               True
# points                   False
# price                     True
# province                  True
# region_1                  True
# region_2                  True
# taster_name               True
# taster_twitter_handle     True
# title                    False
# variety                   True
# winery                   False
# dtype: bool

# %%
# Calculate the percetange of missing data for each column
wine_data.isna().sum()/129971
# Out:
# Unnamed: 0               0.000000
# country                  0.000485
# description              0.000000
# designation              0.288257
# points                   0.000000
# price                    0.069215
# province                 0.000485
# region_1                 0.163475
# region_2                 0.611367
# taster_name              0.201922
# taster_twitter_handle    0.240154
# title                    0.000000
# variety                  0.000008
# winery                   0.000000
# dtype: float64

# %%
# Remove the region columns from the dataset because more than 50% of the values are missing 
wine_data.drop(['Unnamed: 0', 'region_2'], inplace=True, axis=1)
# Visualize the dataset to ensure column was dropped
wine_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-1262ebb69514> in <module>
#       1 # Remove the region columns from the dataset because more than 50% of the values are missing
# ----> 2 wine_data.drop(['Unnamed: 0', 'region_2'], inplace=True, axis=1)
#       3 # Visualize the dataset to ensure column was dropped
#       4 wine_data
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# ...

# %%
# Replace missing values with the average for the column because they are continuous values
wine_data['price'] = wine_data['price'].fillna(wine_data['price'].mean())
# Check to see if all values are filled
wine_data.isnull().mean()*100
# Out:
# country                   0.048472
# description               0.000000
# designation              28.825661
# points                    0.000000
# price                     0.000000
# province                  0.048472
# region_1                 16.347493
# taster_name              20.192197
# taster_twitter_handle    24.015357
# title                     0.000000
# variety                   0.000769
# winery                    0.000000
# Value                     0.000000
# dtype: float64

# %%
wine_data['Value']=wine_data['points']/wine_data['price']
wine_data
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points      price  \
# 0                                 Vulkà Bianco      87  35.363389
# ...

# %%
# Create a new dataframe one for France and one for Italy
grouped_wine = wine_data.groupby('country')
italy_wine = grouped_wine.get_group('Italy')
italy_wine.count()
italy_wine.isna().mean()*100
italy_wine.reset_index()
italy_wine
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...        ...                                                ...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points      price           province  \
# 0                    Vulkà Bianco      87  35.363389  Sicily & Sardinia
# ...

# %%
grouped_wine = wine_data.groupby('country')
france_wine = grouped_wine.get_group('France')
france_wine.count()
france_wine.isna().mean()*100
france_wine
# Out:
#        country                                        description  \
# 7       France  This dry and restrained wine offers spice in p...
# 9       France  This has great depth of flavor with its fresh ...
# 11      France  This is a dry wine, very spicy, with a tight, ...
# 30      France  Red cherry fruit comes laced with light tannin...
# 42      France  This is a festive wine, with soft, ripe fruit ...
# ...        ...                                                ...
# 129964  France  Initially quite muted, this wine slowly develo...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points      price    province  \
# 7                                 NaN      87  24.000000      Alsace
# ...

# %%
# Checking to see the data types we will be dealing with 
wine_data.dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# Value                    float64
# dtype: object

# %%
# Decriptive statistics to help us find what pieces of the data set we might want to analyze
wine_data.describe()
# Out:
#           Unnamed: 0         points          price          Value
# count  129971.000000  129971.000000  129971.000000  129971.000000
# mean    64985.000000      88.447138      35.363389       3.748515
# std     37519.540256       3.039730      39.577066       2.165233
# min         0.000000      80.000000       4.000000       0.026667
# 25%     32492.500000      86.000000      18.000000       2.200000
# 50%     64985.000000      88.000000      28.000000       3.206897
# 75%     97477.500000      91.000000      40.000000       4.944444
# max    129970.000000     100.000000    3300.000000      21.500000

# %%
scatter_plot = plt.figure(figsize=(9,8))
axes2 = scatter_plot.add_subplot(1,1,1)
axes2.scatter(wine_data.points, wine_data.price, s=8) # Sets points as the x-axis and price as the y-axis
axes2.set_title('Price per bottle vs. Points')
axes2.set_ylabel('Price per bottle')
axes2.set_xlabel('Points')
scatter_plot.show()

# %%
# Possible heat map of above graph

# %%
# Calculate average price and score per bottle of wine by country
means = wine_data.groupby('country').mean()
# Create columns to determine average value by country 
means['value'] = means['points'] / means['price']
means
# Out:
#                            Unnamed: 0     points      price     value
# country
# Argentina                65075.723158  86.710263  24.635787  3.519687
# Armenia                  37158.000000  87.500000  14.500000  6.034483
# Australia                65037.539287  88.580507  35.436547  2.499693
# Austria                  65614.296861  90.101345  31.513725  2.859114
# Bosnia and Herzegovina   56613.000000  86.500000  12.500000  6.920000
# Brazil                   54921.634615  84.673077  24.881095  3.403109
# Bulgaria                 67618.170213  87.936170  14.645390  6.004358
# Canada                   70582.365759  89.369650  35.708522  2.502754
# Chile                    64582.882156  86.493515  20.968996  4.124829
# China                   109989.000000  89.000000  18.000000  4.944444
# Croatia                  55757.178082  87.219178  25.722285  3.390802
# Cyprus                   58639.181818  87.181818  16.272727  5.357542
# ...

# %%
# Create a bar chart to display average price by country
wine_data['price'].groupby(wine_data['country']).mean().plot(kind='bar', figsize=(10,9))
plt.title('Average Price by Country')
plt.ylabel('Average Price - $')
# Out:
# Text(0, 0.5, 'Average Price - $')

# %%
# Create a bar chart to display average price by country
wine_data['points'].groupby(wine_data['country']).mean().plot(kind='bar', figsize=(10,9))
plt.title('Average Points by Country')
plt.ylabel('Points')
ax = plt.gca()
ax.set_ylim([80,100])
# Out:
# (80, 100)

# %%
# Create a bar chart to display average value by country
means.plot(y = 'value', kind='bar', figsize=(10,9), legend=False)
plt.title='Average Value by Country'
plt.ylabel='Value'
plt.show()

# %%
import numpy as np
region_wine_count = italy_wine.groupby('region_1')['title'].agg(np.count_nonzero)
region_italy_wine50 = region_wine_count.sort_values(ascending=False).head(50)
region_italy_wine50
# Out:
# region_1
# Barolo                                         1599
# Brunello di Montalcino                         1470
# Toscana                                        1197
# Chianti Classico                               1062
# Sicilia                                         925
# Barbaresco                                      794
# Alto Adige                                      694
# Amarone della Valpolicella Classico             420
# Collio                                          379
# Rosso di Montalcino                             338
# Etna                                            268
# Franciacorta                                    256
# Vino Nobile di Montepulciano                    252
# Conegliano Valdobbiadene Prosecco Superiore     251
# Colli Orientali del Friuli                      217
# Bolgheri                                        214
# Terre Siciliane                                 213
# Morellino di Scansano                           190
# ...

# %%
# Groups Italy wine dataframe by region
italyregion_grouped = italy_wine.groupby('region')
italy_wine = grouped_wine.get_group('')

# %%
# Grouping Italy by region and running descriptive statistics on average values
italy_wine_stats = italy_wine.groupby('region_1')['Value'].agg([np.min, np.max, np.mean, np.std])
# Graphs top 10 regions in Italy sorted by average value
italy_wine_stats['mean'].sort_values(ascending=False).head(10).plot(kind='bar',figsize = (10,9))
plt.title('Top 10 Regions by Avg. Value in Italy')
plt.xlabel('Italian Region')
plt.ylabel('Value Score')
# Question 1: On average, which region has the best value?
# Data to support question 1 below
# Out:
# Text(0, 0.5, 'Value Score')

# %%
# Grouping France by region and running descriptive statistics on average values
france_wine_stats = france_wine.groupby('region_1')['Value'].agg([np.min, np.max, np.mean, np.std])
#
france_win
