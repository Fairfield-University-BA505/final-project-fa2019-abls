# %%
# Import pandas
import pandas as pd
# Import matplotlib to plot data
import matplotlib.pylab as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
# Import data set
wine_data_program = pd.read_csv('wine_data.csv')
# Visualize data set
#wine_data_program.head()

# %%
# Remove the region columns from the dataset because more than 50% of the values are missing 
wine_data_program.drop(['Unnamed: 0', 'region_2'], inplace=True, axis=1)
# Visualize the dataset to ensure column was dropped
#wine_data_program

# %%
# Replace missing values with the average for the column because they are continuous values
wine_data_program['price'] = wine_data_program['price'].fillna(wine_data_program['price'].mean())
# Check to see if all values are filled
wine_data_program.isnull().mean()*100
# Out:
# country                   0.048472
# description               0.000000
# designation              28.825661
# points                    0.000000
# price                     0.000000
# province                  0.048472
# region_1                 16.347493
# taster_name              20.192197
# taster_twitter_handle    24.015357
# title                     0.000000
# variety                   0.000769
# winery                    0.000000
# dtype: float64

# %%
# Add column to wine_data set to analyze data by points per dollar
wine_data_program['Value']=wine_data_program['points']/wine_data_program['price']
#wine_data_program.head()

# %%
def wine_recommend():
    try:
        print("Please enter your desired wine country: ")
        country_input = input()
        print("Please enter your desired wine variety: ")
        variety_input = input()
        print('Please enter your desired price: ')
        price_input= float(input())
        print('Please enter your desired points: ')
        points_input = int(input())
        rec_df = wine_data_program[(wine_data_program.country==country_input) & (wine_data_program.variety==variety_input) & (wine_data_program.price <= price_input) & (wine_data_program.points >= points_input)].sort_values('points', ascending = 0)
        return(rec_df.head(10))
   
    except:
        print('Input Error, please enter a valid input')

# %%
wine_recommend()
# Out:
# Please enter your desired wine country:
#  Italy
# Please enter your desired wine variety:
#  Pinot Grigio
# Please enter your desired price:
#  50
# Please enter your desired points:
#  80
#        country                                        description designation  \
# 26095    Italy  Bressan proves that Pinot Grigio can obtain sk...         NaN
# 119634   Italy  Bressan proves that Pinot Grigio can obtain sk...         NaN
# 45444    Italy  This is a radically different Pinot Grigio tha...         NaN
# 115211   Italy  Here's a savory Pinot Grigio that's loaded wit...         NaN
# 81368    Italy  Round and juicy, this opens with aromas of sto...         NaN
# 82633    Italy  Pinot Grigio doesn't get better than this. Fre...  Unterebner
# 72935    Italy  Full-bodied and elegant, this opens with aroma...     Passion
# 32419    Italy  Enticing scents of chamomile, white spring flo...       Anger
# 9041     Italy  Here's a polished Pinot Grigio with character....         NaN
